# %%
import os
import json
import pandas as pd
import traceback

# %%
# !pip show langchain-openai
# Out:
# Name: langchain-openai
# Version: 1.1.0
# Summary: An integration package connecting OpenAI and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/openai
# Author:
# Author-email:
# License: MIT
# Location: c:\users\kiit0001\mcqgen\env310\lib\site-packages
# Requires: langchain-core, openai, tiktoken
# Required-by:

# %%
import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# None

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
KEY=os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.5
)
